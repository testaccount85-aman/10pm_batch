# %%
import pandas as pd

# %%
data = pd.read_csv(r"dataset\chicago.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  object
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: object(4)
# memory usage: 1002.1+ KB

# %%
data.isna().sum()
# Out:
# Name                      0
# Position Title            0
# Department                0
# Employee Annual Salary    0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                       Name                  Position Title        Department  \
# 0          AARON,  ELVIA J                WATER RATE TAKER       WATER MGMNT
# 1        AARON,  JEFFERY M                  POLICE OFFICER            POLICE
# 2           AARON,  KARINA                  POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV       WATER MGMNT
# ...                    ...                             ...               ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#       Employee Annual Salary
# ...

# %%
name = "Amanpreet Singh"
a = "My-name_is-aman"

# %%
a.split('_')
# Out:
# ['My-name', 'is-aman']

# %%
data["Employee Annual Salary"] = data["Employee Annual Salary"].str.replace("$" , "").astype("float")

# %%
data["Department"] = data["Department"].str.replace("MGMNT" , "MANAGEMENT" )

# %%
c1 = data["Position Title"].str.startswith("WATER")
data[c1]
# Out:
#                          Name           Position Title        Department  \
# 0             AARON,  ELVIA J         WATER RATE TAKER  WATER MANAGEMENT
# 671           ANDER,  PERRY A         WATER CHEMIST II  WATER MANAGEMENT
# 1054         ASHLEY,  KARMA T         WATER CHEMIST II  WATER MANAGEMENT
# 1079        ATKINS,  JOANNA M         WATER CHEMIST II  WATER MANAGEMENT
# 1181       AZEEM,  MOHAMMED A         WATER CHEMIST II  WATER MANAGEMENT
# ...                       ...                      ...               ...
# 28574      THREATT,  DENISE R  WATER QUALITY INSPECTOR  WATER MANAGEMENT
# 28602       TIGNOR,  DARRYL B         WATER RATE TAKER  WATER MANAGEMENT
# 28955  TRAVIS COOK,  LESLIE R         WATER RATE TAKER  WATER MANAGEMENT
# 29584        VELAZQUEZ,  JOHN         WATER RATE TAKER  WATER MANAGEMENT
# 30239     WASHINGTON,  JOSEPH        WATER CHEMIST III  WATER MANAGEMENT
#
#        Employee Annual Salary
# 0                     90744.0
# ...

# %%
c1 = data["Position Title"].str.endswith("WATER")
data[c1]
# Out:
# Empty DataFrame
# Columns: [Name, Position Title, Department, Employee Annual Salary]
# Index: []

# %%
c2 = data["Position Title"].str.lower().str.contains("water")
data[c2]
# Out:
#                        Name                                 Position Title  \
# 0           AARON,  ELVIA J                               WATER RATE TAKER
# 554      ALUISE,  VINCENT G             FOREMAN OF WATER PIPE CONSTRUCTION
# 671         ANDER,  PERRY A                               WATER CHEMIST II
# 685     ANDERSON,  ANDREW J  DISTRICT SUPERINTENDENT OF WATER DISTRIBUTION
# 702       ANDERSON,  DONALD             FOREMAN OF WATER PIPE CONSTRUCTION
# ...                     ...                                            ...
# 29669        VERMA,  ANUPAM           MANAGING ENGINEER - WATER MANAGEMENT
# 30239   WASHINGTON,  JOSEPH                              WATER CHEMIST III
# 30544       WEST,  THOMAS R                   GEN SUPT OF WATER MANAGEMENT
# 30991    WILLIAMS,  MATTHEW             FOREMAN OF WATER PIPE CONSTRUCTION
# 31405  WOODRIDGE,  ROBERT L             FOREMAN OF WATER PIPE CONSTRUCTION
#
#              Department  Employee Annual Salary
# ...

# %%
#water  , Water , WATER -> water == water

# %%
names = data["Name"].str.split("," , expand=True)

# %%
names.columns = ["lastname" , "firstname"]

# %%
names.rename(columns={"lastname":"Last Name" , "firstname":"First Name"} , inplace=True)

# %%
names = names[["First Name" , "Last Name"]]

# %%
data = pd.concat([names , data] , axis=1).drop(columns=["Name"])

# %%
data.to_csv("new_Data.csv")

# %%
def aman(value):
    return float(value.replace('$' , ""))

# %%
data["Employee Annual Salary"]= data["Employee Annual Salary"].apply(aman)

# %%
data
# Out:
#                       Name                  Position Title        Department  \
# 0          AARON,  ELVIA J                WATER RATE TAKER       WATER MGMNT
# 1        AARON,  JEFFERY M                  POLICE OFFICER            POLICE
# 2           AARON,  KARINA                  POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV       WATER MGMNT
# ...                    ...                             ...               ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#        Employee Annual Salary
# ...

# %%
pd.read_excel(r"dataset/Data - Single Worksheet.xlsx")
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
data = pd.read_excel(r"dataset/Data - Multiple Worksheets.xlsx", sheet_name=None)

# %%
df= pd.concat([data["Data 1"] ,data["Data 2"]  ,  data["Data 3"]]  , ignore_index=True)

# %%
df
# Out:
#    First Name Last Name           City Gender
# 0     Brandon     James          Miami      M
# 1        Sean   Hawkins         Denver      M
# 2        Judy       Day    Los Angeles      F
# 3      Ashley      Ruiz  San Francisco      F
# 4   Stephanie     Gomez       Portland      F
# 5      Parker     Power        Raleigh      F
# 6     Preston  Prescott   Philadelphia      F
# 7     Ronaldo   Donaldo         Bangor      M
# 8       Megan   Stiller  San Francisco      M
# 9      Bustin    Jieber         Austin      F
# 10     Parker     Power        Raleigh      F
# 11    Preston  Prescott   Philadelphia      F
# 12    Ronaldo   Donaldo         Bangor      M
# 13      Megan   Stiller  San Francisco      M
# 14     Bustin    Jieber         Austin      F
