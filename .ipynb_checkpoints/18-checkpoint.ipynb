# %%
import pandas as pd

# %%
data = pd.read_csv(r"dataset/fortune1000.csv")

# %%
data.set_index("Rank" , inplace=True)

# %%
data.reset_index()
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
sector = data.groupby("Sector")

# %%
sector.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
data["Sector"].value_counts().sort_index()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# Name: count, dtype: int64

# %%
sector.get_group("Energy")
# Out:
#                         Company  Sector                      Industry  \
# Rank
# 2                   Exxon Mobil  Energy            Petroleum Refining
# 14                      Chevron  Energy            Petroleum Refining
# 30                  Phillips 66  Energy            Petroleum Refining
# 32                Valero Energy  Energy            Petroleum Refining
# 42           Marathon Petroleum  Energy            Petroleum Refining
# ...                         ...     ...                           ...
# 981                  WPX Energy  Energy  Mining, Crude-Oil Production
# 983    Adams Resources & Energy  Energy            Petroleum Refining
# 995                   EP Energy  Energy  Mining, Crude-Oil Production
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
#
#              Location  Revenue  Profits  Employees
# Rank
# 2          Irving, TX   246204    16150      75600
# ...

# %%
sector.agg({"Revenue":"sum" , "Profits":"sum" , "Employees":"mean"})
# Out:
#                               Revenue  Profits     Employees
# Sector
# Aerospace & Defense            357940    28742  48402.850000
# Apparel                         95968     8236  23093.133333
# Business Services              272195    28227  26687.254902
# Chemicals                      243897    22628  15455.033333
# Energy                        1517809   -73447   9745.303279
# Engineering & Construction     153983     5304  15642.615385
# Financials                    2217159   260209  24172.287770
# Food and Drug Stores           483769    16759  93026.533333
# Food, Beverages & Tobacco      555967    51417  28177.488372
# Health Care                   1614707   106114  35710.520000
# Hotels, Resturants & Leisure   169546    20697  99369.800000
# Household Products             234737    14428  23072.785714
# Industrials                    497581    20764  33591.934783
# Materials                      259145     4428  14840.069767
# ...

# %%
data = pd.read_csv(r"dataset/covid_dataset/raw_data1.csv")

# %%
data["Current Status"]
# Out:
# 0           Recovered
# 1           Recovered
# 2           Recovered
# 3           Recovered
# 4           Recovered
#              ...
# 17359    Hospitalized
# 17360    Hospitalized
# 17361    Hospitalized
# 17362    Hospitalized
# 17363    Hospitalized
# Name: Current Status, Length: 17364, dtype: object

# %%
data.columns
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Estimated Onset Date', 'Age Bracket', 'Gender', 'Detected City',
#        'Detected District', 'Detected State', 'State code', 'Current Status',
#        'Notes', 'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes', 'Num Cases'],
#       dtype='object')

# %%
"""
1.Read All the 12 files using loop and concat all the df into 1 DataFrame 
2.Use these columns -> 'Date Announced','Age Bracket', 'Gender', 'Detected City',
       'Detected District', 'Detected State', 'Current Status','Num Cases'
3.Split the 'Date Announced' column and get Date , Month and Year As Diffrent column once done remove
    'Date Announced' column
4.Age wise , Gender wise , year wise , month wise , state wise , city wise -> sum of number of cases 
-> also current status 


"""

# %%
pd.read_xml(r"dataset/aman.xml")
# Out:
#      name            email grade  age
# 0    John    john@mail.com     A   16
# 1   Alice   alice@mail.com     B   17
# 2     Bob     bob@mail.com     C   16
# 3  Hannah  hannah@mail.com     A   17

# %%
pd.read_csv(r"dataset/abc.tsv" , delimiter="\t")
# Out:
#                               Wow... Loved this place.  1
# 0                                   Crust is not good.  0
# 1            Not tasty and the texture was just nasty.  0
# 2    Stopped by during the late May bank holiday of...  1
# 3    The selection on the menu was great and so wer...  1
# 4       Now I am getting angry and I want my damn pho.  0
# ..                                                 ... ..
# 994  I think food should have flavor and texture an...  0
# 995                           Appetite instantly gone.  0
# 996  Overall I was not impressed and would not go b...  0
# 997  The whole experience was underwhelming, and I ...  0
# 998  Then, as if I hadn't wasted enough of my life ...  0
#
# [999 rows x 2 columns]

# %%
pd.read_json(r"dataset/multi_line.json")
# Out:
#        id first_name   last_name    birthday                       email  \
# 0       1     Ardene  Charleston  19.06.2019     acharleston0@smh.com.au
# 1       2    Alfonso       Coull  27.10.2019       acoull1@newyorker.com
# 2       3      Arley     Caldron  27.11.2019  acaldron2@miitbeian.gov.cn
# 3       4     Blanch      Bennie  11.06.2020          bbennie3@bbc.co.uk
# 4       5     Putnam        Vain  19.06.2019              pvain4@ovh.net
# ..    ...        ...         ...         ...                         ...
# 995   996     Shelby      Odhams  02.04.2020       sodhamsrn@sina.com.cn
# 996   997    Amaleta       Inett  29.08.2019       ainettro@sakura.ne.jp
# 997   998     Leland   Castleton  01.12.2019    lcastletonrp@twitpic.com
# 998   999    Devonna    Garralts  15.02.2020          dgarraltsrq@va.gov
# 999  1000      Allan       Boyet  04.01.2020          aboyetrr@vimeo.com
#
#                                                address  \
# ...

# %%
pd.read_json(r"dataset/single_line.json" , lines=True)
# Out:
#        id first_name    last_name    birthday                           email  \
# 0       1     Noelyn   Novichenko  04.08.2019          nnovichenko0@imgur.com
# 1       2    Linnell    Langthorn  10.02.2020             llangthorn1@mtv.com
# 2       3     Phoebe    Dranfield  03.11.2019        pdranfield2@marriott.com
# 3       4       Maxy     Ickowicz  19.05.2020        mickowicz3@earthlink.net
# 4       5    Cherlyn   Rosenbusch  08.07.2019            crosenbusch4@free.fr
# ..    ...        ...          ...         ...                             ...
# 995   996      Lilla   Clemintoni  01.03.2020     lclemintonirn@homestead.com
# 996   997    Sosanna  Kubasiewicz  03.05.2020        skubasiewiczro@state.gov
# 997   998   Meredeth        Meuse  28.02.2020            mmeuserp@smugmug.com
# 998   999       Darn  Scartifield  23.07.2019  dscartifieldrq@dagondesign.com
# 999  1000  Philomena       Petrie  12.05.2020         ppetrierr@wordpress.org
#
# ...
